# %%
# %%time 

# !unzip '/content/drive/MyDrive/Colab Notebooks/PROGETTO MUSICA DSIM/DATASET/DATASET_3_SEC/DATASET_3_SEC.zip' -d '/content'

# %%
import librosa 
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
import librosa.display
import pylab
from matplotlib import cm

# %%
# %%time

n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Blues/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/blues/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('//content/DATASET_3_SEC/blues/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_blues_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_blues = librosa.amplitude_to_db(mel_blues_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_blues, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()
# Out:
# CPU times: user 2min 9s, sys: 2min 39s, total: 4min 49s
# Wall time: 5min 52s

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Classical/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/classical/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/classical/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_classical_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_classical = librosa.amplitude_to_db(mel_classical_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_classical, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Country/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/country/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/country/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_country_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_country = librosa.amplitude_to_db(mel_country_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_country, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Disco/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/disco/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/disco/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_disco_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_disco = librosa.amplitude_to_db(mel_disco_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_disco, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/HipHop/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/hiphop/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/hiphop/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_hiphop_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_hiphop = librosa.amplitude_to_db(mel_hiphop_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_hiphop, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Jazz/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/jazz/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/jazz/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_jazz_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_jazz = librosa.amplitude_to_db(mel_jazz_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_jazz, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Metal/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/metal/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/metal/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_metal_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_metal = librosa.amplitude_to_db(mel_metal_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_metal, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Pop/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/pop/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/pop/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_pop_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_pop = librosa.amplitude_to_db(mel_pop_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_pop, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Reggae/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/reggae/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('//content/DATASET_3_SEC/reggae/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_reggae_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_reggae = librosa.amplitude_to_db(mel_reggae_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_reggae, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
n_fft=2048
hop_length=512
IMG_DIR='/content/MEL_DATASET_3_SEC/Rock/'

for f in sorted(os.listdir('/content/DATASET_3_SEC/rock/')):
        if f.endswith('.wav'):

            # Load file and compute the requested features
            y, sr = librosa.load('/content/DATASET_3_SEC/rock/' + f)
            y_, sr_ = librosa.effects.trim(y)

            # Mel Spectogram
            mel_rock_= librosa.feature.melspectrogram(y_, sr=sr, n_fft=n_fft, hop_length=hop_length)
            mel_rock = librosa.amplitude_to_db(mel_rock_, ref=np.max)
        
            # Plotting the spectrogram and save as JPG without axes (just the image)
            pylab.figure(figsize=(3,3))
            pylab.axis('off') 
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
            librosa.display.specshow(mel_rock, cmap='cool')
            pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
            pylab.close()

# %%
import shutil
shutil.make_archive('MEL_DATASET_3_SEC', 'zip', 'MEL_DATASET_3_SEC')
# Out:
# '/content/MEL_DATASET_3_SEC.zip'
